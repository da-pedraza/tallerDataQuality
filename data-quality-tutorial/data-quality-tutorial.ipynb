# %% [markdown]
# # Data Quality Tutorial
#
# Dataset: Homicidos, Colombia

# %%
# Importing required libraries
import re
from random import randint
from datetime import datetime

import numpy as np
import pandas as pd

import pylev

# %%
# Parameter for showing all columns when printing a dataframe
pd.set_option('display.max_columns', None)

# %%
# Loading data
homicides_df = pd.read_csv("./data/homicides.csv")

# %%
# Printing the dataset dimensions
homicides_df.shape
# Out:
# (12400, 23)

# %%
# Printing column data types
homicides_df.dtypes
# Out:
# FECHA                 object
# DEPARTAMENTO          object
# MUNICIPIO             object
# DIA                   object
# HORA                  object
# BARRIO                object
# ZONA                  object
# CLASE DE SITIO        object
# ARMA O MEDIO          object
# MOVIL VICTIMA         object
# MOVIL AGRESOR         object
# EDAD                 float64
# GENERO                object
# ESTADO CIVIL          object
# CLASE EMPLEADO        object
# PROFESION             object
# ESCOLARIDAD           object
# PAIS NACE             object
# CODIGO DANE          float64
# 2015                   int64
# AÑO DE NACIMIENTO    float64
# CÉDULA                object
# CORREO                object
# dtype: object

# %%
homicides_df.head(20)
# Out:
#                      FECHA DEPARTAMENTO             MUNICIPIO     DIA   HORA  \
# 0   01/01/2015 12:00:00 AM    ANTIOQUIA                 AMAGÁ  Jueves   6:00
# 1   01/01/2015 12:00:00 AM    ANTIOQUIA               BARBOSA  Jueves   9:00
# 2   01/01/2015 12:00:00 AM    ANTIOQUIA              EL BAGRE  Jueves  19:00
# 3   01/01/2015 12:00:00 AM    ANTIOQUIA                JARDÍN  Jueves  11:20
# 4   01/01/2015 12:00:00 AM    ANTIOQUIA         MEDELLÍN (CT)   Juees  15:00
# 5   01/01/2015 12:00:00 AM    ANTIOQUIA         MEDELLÍN (CT)   Juees   0:47
# 6   01/01/2015 12:00:00 AM    ANTIOQUIA         MEDELLÍN (CT)  Jueves  11:00
# 7   01/01/2015 12:00:00 AM    ANTIOQUIA         MEDELLÍN (CT)  Jueves  19:35
# 8   01/01/2015 12:00:00 AM    ANTIOQUIA         MEDELLÍN (CT)  Jueves  20:35
# 9   01/01/2015 12:00:00 AM    ANTIOQUIA                MUTATÁ  Jueves  14:00
# 10  01/01/2015 12:00:00 AM    ANTIOQUIA               NECOCLÍ  Jueves   5:00
# 11  01/01/2015 12:00:00 AM    ANTIOQUIA  SANTAFÉ DE ANTIOQUIA  Jueves  23:30
# 12  01/01/2015 12:00:00 AM    ANTIOQUIA               SEGOVIA  Jueves   9:30
# 13  01/01/2015 12:00:00 AM    ANTIOQUIA               TÁMESIS  Jueves  14:00
# 14  01/01/2015 12:00:00 AM    ATLÁNTICO     BARRANQUILLA (CT)   Juees  14:40
# 15  01/01/2015 12:00:00 AM    ATLÁNTICO     BARRANQUILLA (CT)  Jueces   4:40
# 16  01/01/2015 12:00:00 AM    ATLÁNTICO     BARRANQUILLA (CT)  Jueves   6:00
# 17  01/01/2015 12:00:00 AM    ATLÁNTICO     BARRANQUILLA (CT)  Jueves   9:50
# 18  01/01/2015 12:00:00 AM    ATLÁNTICO     BARRANQUILLA (CT)  Jueves  20:00
# 19  01/01/2015 12:00:00 AM    ATLÁNTICO               SOLEDAD   juves   8:30
#
#                         BARRIO    ZONA                      CLASE DE SITIO  \
# 0                    EL VOLCAN   RURAL                              TIENDA
# 1               VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2                PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                   CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4     PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 5       CORDOBA CNO REPORTADO7  URBANA                       VIAS PUBLICAS
# 6   CRISTO REY CNO REPORTADO15  URBANA                       VIAS PUBLICAS
# 7     LA SALLE  CNO REPORTADO3  URBANA                       VIAS PUBLICAS
# 8       KENNEDY CNO REPORTADO6  URBANA                       VIAS PUBLICAS
# 9                VDA CASA ROJA   RURAL                  FINCAS Y SIMILARES
# 10             CGTO. EL TOTUMO   RURAL                  FINCAS Y SIMILARES
# 11             SECTOR TERMINAL  URBANA                         LOTE BALDIO
# 12                       GALAN  URBANA                       VIAS PUBLICAS
# 13                   SAN PABLO   RURAL                  FINCAS Y SIMILARES
# 14                LAS AMERICAS  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 15                  BARLOVENTO  URBANA                       VIAS PUBLICAS
# 16                      REBOLO  URBANA                       VIAS PUBLICAS
# 17                      REBOLO  URBANA                       VIAS PUBLICAS
# 18                     POR FIN  URBANA                       VIAS PUBLICAS
# 19                   LAS MORAS  URBANA                       VIAS PUBLICAS
#
#      ARMA O MEDIO MOVIL VICTIMA         MOVIL AGRESOR  EDAD     GENERO  \
# 0     ARMA BLANCA         A PIE                 A PIE  44.0  MASCULINO
# 1     ARMA BLANCA         A PIE                 A PIE  30.0  MASCULINO
# 2     ARMA BLANCA         A PIE                 A PIE  33.0  MASCULINO
# 3     ARMA BLANCA         A PIE                 A PIE  40.0  MASCULINO
# 4    CONTUNDENTES         A PIE                 A PIE  66.0  MASCULINO
# 5   ARMA DE FUEGO         A PIE                 A PIE  42.0  MASCULINO
# 6     ARMA BLANCA         A PIE                 A PIE  25.0  MASCULINO
# 7     ARMA BLANCA         A PIE                 A PIE  37.0  MASCULINO
# 8   ARMA DE FUEGO         A PIE  PASAJERO MOTOCICLETA  25.0  MASCULINO
# 9     ARMA BLANCA         A PIE                 A PIE  30.0  MASCULINO
# 10    ARMA BLANCA         A PIE                 A PIE  41.0  MASCULINO
# 11  ARMA DE FUEGO         A PIE                 A PIE  30.0  MASCULINO
# 12    ARMA BLANCA         A PIE                 A PIE  29.0  MASCULINO
# 13    ARMA BLANCA         A PIE                 A PIE  40.0  MASCULINO
# 14  ARMA DE FUEGO         A PIE                 A PIE  21.0  MASCULINO
# 15  ARMA DE FUEGO         A PIE                 A PIE  20.0  MASCULINO
# 16  ARMA DE FUEGO         A PIE                 A PIE  32.0  MASCULINO
# 17  ARMA DE FUEGO         A PIE                 A PIE  39.0   FEMENINO
# 18  ARMA DE FUEGO         A PIE  PASAJERO MOTOCICLETA  17.0  MASCULINO
# 19  ARMA DE FUEGO         A PIE                 A PIE  33.0  MASCULINO
#
#    ESTADO CIVIL  CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  \
# 0        CASADO   INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 1       SOLTERO     DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO
# 2   UNION LIBRE      AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 3        CASADO      AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 4   UNION LIBRE     DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA
# 5       SOLTERO   INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 6       SOLTERO     DESEMPLEADO  NO REPORTADO  SECUNDARIA      COLOMBIA
# 7        CASADO   INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 8       SOLTERO   INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 9       SOLTERO  ETNIA INDIGENA  NO REPORTADO  SECUNDARIA  NO REPORTADO
# 10  UNION LIBRE      AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 11      SOLTERO     DESEMPLEADO  NO REPORTADO  ANALFABETA      COLOMBIA
# 12      SOLTERO   INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 13      SOLTERO      AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 14      SOLTERO   INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 15      SOLTERO   INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 16  UNION LIBRE   INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 17      SOLTERO     COMERCIANTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 18      SOLTERO     DESEMPLEADO  NO REPORTADO  SECUNDARIA      COLOMBIA
# 19      SOLTERO   INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
#
#     CODIGO DANE  2015  AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0     5030000.0     1             1971.0  42-908  agbnqg2122@unidatos.edu.co
# 1     5079000.0     1             1985.0  15-183        rbkeui3584@gmail.com
# 2     5250000.0     1             1982.0  84-786  aorkhf9155@unidatos.edu.co
# 3     5364000.0     1             1975.0  31-289  dhtemr6623@unidatos.edu.co
# 4     5001000.0     1             1949.0  66-363  artatj9268@unidatos.edu.co
# 5     5001000.0     1             1973.0  54-450  grlcsj8696@unidatos.edu.co
# 6     5001000.0     1             1990.0  45-052        pkdakc6682@gmail.com
# 7     5001000.0     1             1978.0  45-298        qledtq1884@gmail.com
# 8     5001000.0     1             1990.0  37-281  mipgfg2758@unidatos.edu.co
# 9     5480000.0     1             1985.0  78-013  dgepmg5536@unidatos.edu.co
# 10    5490000.0     1             1974.0  23-787  lngclq5845@unidatos.edu.co
# 11    5042000.0     1             1985.0  49-898  alsmgs8974@unidatos.edu.co
# 12    5736000.0     1             1986.0  98-587  inugoi5195@unidatos.edu.co
# 13    5789000.0     1             1975.0  39-330        nsirqk5181@gmail.com
# 14    8001000.0     1             1994.0  26-603  nnofur6404@unidatos.edu.co
# 15    8001000.0     1             1995.0  51-967  clfagt5842@unidatos.edu.co
# 16    8001000.0     1             1983.0  65-056  bspmmr7169@unidatos.edu.co
# 17    8001000.0     1             1976.0  33-026  ibuoap4440@unidatos.edu.co
# 18    8001000.0     1             1998.0  83-291  qdqasa2516@unidatos.edu.co
# 19    8758000.0     1             1982.0  52-287        shfbpo7917@gmail.com

# %%
# Deleting constant column

del homicides_df["2015"]

# %%
homicides_df.head()
# Out:
#                     FECHA DEPARTAMENTO      MUNICIPIO     DIA   HORA  \
# 0  01/01/2015 12:00:00 AM    ANTIOQUIA          AMAGÁ  Jueves   6:00
# 1  01/01/2015 12:00:00 AM    ANTIOQUIA        BARBOSA  Jueves   9:00
# 2  01/01/2015 12:00:00 AM    ANTIOQUIA       EL BAGRE  Jueves  19:00
# 3  01/01/2015 12:00:00 AM    ANTIOQUIA         JARDÍN  Jueves  11:20
# 4  01/01/2015 12:00:00 AM    ANTIOQUIA  MEDELLÍN (CT)   Juees  15:00
#
#                      BARRIO    ZONA                      CLASE DE SITIO  \
# 0                 EL VOLCAN   RURAL                              TIENDA
# 1            VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2             PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4  PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
#
#    ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 0   ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO       CASADO
# 1   ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO      SOLTERO
# 2   ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO  UNION LIBRE
# 3   ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO       CASADO
# 4  CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO  UNION LIBRE
#
#   CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  CODIGO DANE  \
# 0  INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA    5030000.0
# 1    DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO    5079000.0
# 2     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5250000.0
# 3     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5364000.0
# 4    DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA    5001000.0
#
#    AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0             1971.0  42-908  agbnqg2122@unidatos.edu.co
# 1             1985.0  15-183        rbkeui3584@gmail.com
# 2             1982.0  84-786  aorkhf9155@unidatos.edu.co
# 3             1975.0  31-289  dhtemr6623@unidatos.edu.co
# 4             1949.0  66-363  artatj9268@unidatos.edu.co

# %%
# Creating a lambda expression for datetime parsing
dateparse = lambda x: datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")

# %%
# Applying the validation to all values in column
#homicides_df["FECHA"].apply(dateparse)
# IT IS EXPECTED TO HAVE AN ERROR INTENTIONALLY

# %%
# Creating a function for validating which value is causing the previous error
def error_in_format(x):
    try:
        datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")
        return False
    except:
        return True

# %%
# Using the function for validation
homicides_df.loc[homicides_df["FECHA"].apply(error_in_format)]

# THE LAST ERROR IS CAUSING THE ERROR
# Out:
#        FECHA DEPARTAMENTO MUNICIPIO  DIA HORA BARRIO ZONA CLASE DE SITIO  \
# 12399  TOTAL          NaN       NaN  NaN  NaN    NaN  NaN            NaN
#
#       ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD GENERO ESTADO CIVIL  \
# 12399          NaN           NaN           NaN   NaN    NaN          NaN
#
#       CLASE EMPLEADO PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  \
# 12399            NaN       NaN         NaN       NaN          NaN
#
#        AÑO DE NACIMIENTO CÉDULA CORREO
# 12399                NaN    NaN    NaN

# %%
# Deleting an error by its index
homicides_df = homicides_df.drop([12399])

# %%
# Trying to parse the datetime string again
homicides_df["FECHA"] = homicides_df["FECHA"].apply(dateparse)

# %%
# Counting homicides hour
homicides_df["FECHA"].dt.hour.value_counts()

# All datetime hour parts are the same
# Out:
# 12    12399
# Name: FECHA, dtype: int64

# %%
# The homicide hour is available in a different column!!!
# Merging both columns
homicides_df["FECHA"] = homicides_df["FECHA"].astype(str).apply(lambda x: x[:11]) + homicides_df["HORA"]

# %%
del homicides_df["HORA"]

# %%
homicides_df["FECHA"].head()
# Out:
# 0     2015-01-01 6:00
# 1     2015-01-01 9:00
# 2    2015-01-01 19:00
# 3    2015-01-01 11:20
# 4    2015-01-01 15:00
# Name: FECHA, dtype: object

# %%
# Making a new expression for datetime parsing
dateparse = lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M")

# %%
# Applying the expression
homicides_df["FECHA"] = homicides_df["FECHA"].apply(dateparse)

# %%
homicides_df.dtypes
# Out:
# FECHA                datetime64[ns]
# DEPARTAMENTO                 object
# MUNICIPIO                    object
# DIA                          object
# BARRIO                       object
# ZONA                         object
# CLASE DE SITIO               object
# ARMA O MEDIO                 object
# MOVIL VICTIMA                object
# MOVIL AGRESOR                object
# EDAD                        float64
# GENERO                       object
# ESTADO CIVIL                 object
# CLASE EMPLEADO               object
# PROFESION                    object
# ESCOLARIDAD                  object
# PAIS NACE                    object
# CODIGO DANE                 float64
# AÑO DE NACIMIENTO           float64
# CÉDULA                       object
# CORREO                       object
# dtype: object

# %%
homicides_df.head()
# Out:
#                 FECHA DEPARTAMENTO      MUNICIPIO     DIA  \
# 0 2015-01-01 06:00:00    ANTIOQUIA          AMAGÁ  Jueves
# 1 2015-01-01 09:00:00    ANTIOQUIA        BARBOSA  Jueves
# 2 2015-01-01 19:00:00    ANTIOQUIA       EL BAGRE  Jueves
# 3 2015-01-01 11:20:00    ANTIOQUIA         JARDÍN  Jueves
# 4 2015-01-01 15:00:00    ANTIOQUIA  MEDELLÍN (CT)   Juees
#
#                      BARRIO    ZONA                      CLASE DE SITIO  \
# 0                 EL VOLCAN   RURAL                              TIENDA
# 1            VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2             PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4  PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
#
#    ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 0   ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO       CASADO
# 1   ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO      SOLTERO
# 2   ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO  UNION LIBRE
# 3   ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO       CASADO
# 4  CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO  UNION LIBRE
#
#   CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  CODIGO DANE  \
# 0  INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA    5030000.0
# 1    DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO    5079000.0
# 2     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5250000.0
# 3     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5364000.0
# 4    DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA    5001000.0
#
#    AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0             1971.0  42-908  agbnqg2122@unidatos.edu.co
# 1             1985.0  15-183        rbkeui3584@gmail.com
# 2             1982.0  84-786  aorkhf9155@unidatos.edu.co
# 3             1975.0  31-289  dhtemr6623@unidatos.edu.co
# 4             1949.0  66-363  artatj9268@unidatos.edu.co

# %%
# Creating a dictionary representing the valid departments for Colombia
departments_list = ['ANTIOQUIA', 'ATLÁNTICO', 'BOLÍVAR', 'BOYACÁ', 'CALDAS', 'CAQUETÁ',
       'CASANARE', 'CAUCA', 'CESAR', 'CHOCÓ', 'CÓRDOBA', 'META',
       'CUNDINAMARCA', 'HUILA', 'MAGDALENA', 'NARIÑO', 'PUTUMAYO',
       'RISARALDA', 'SANTANDER', 'SUCRE', 'TOLIMA', 'VALLE',
       'NORTE DE SANTANDER', 'GUAJIRA', 'QUINDÍO', 'SAN ANDRÉS Y PROVIDENCIA', 'ARAUCA',
       'GUAINÍA', 'VICHADA', 'VAUPÉS', 'GUAVIARE', 'AMAZONAS']

# %%
# Finding values not matching with the dictionary
homicides_df.loc[~homicides_df["DEPARTAMENTO"].isin(departments_list), "DEPARTAMENTO"].unique()
# Out:
# array(['SAN ANDRÉS', 'N. DE SANTANDER'], dtype=object)

# %% [markdown]
# <span style="color:red">TODO: Check and replace, if apply, the values identified as error because do not match with the dictionary</span>

# %%
homicides_df["DEPARTAMENTO"].value_counts()
# Out:
# VALLE                       2596
# ANTIOQUIA                   1895
# CUNDINAMARCA                1799
# CAUCA                        591
# ATLÁNTICO                    568
# NARIÑO                       439
# BOLÍVAR                      403
# TOLIMA                       328
# RISARALDA                    313
# META                         306
# NORTE DE SANTANDER           279
# SANTANDER                    277
# QUINDÍO                      271
# CÓRDOBA                      266
# CALDAS                       219
# CESAR                        218
# HUILA                        204
# MAGDALENA                    192
# GUAJIRA                      183
# CAQUETÁ                      178
# CHOCÓ                        158
# PUTUMAYO                     145
# SUCRE                        131
# BOYACÁ                       112
# N. DE SANTANDER               87
# ARAUCA                        79
# CASANARE                      77
# GUAVIARE                      34
# VICHADA                       17
# SAN ANDRÉS                    14
# AMAZONAS                       9
# VAUPÉS                         5
# SAN ANDRÉS Y PROVIDENCIA       4
# GUAINÍA                        2
# Name: DEPARTAMENTO, dtype: int64

# %%
homicides_df.loc[homicides_df["DEPARTAMENTO"] == "SAN ANDRÉS", "DEPARTAMENTO"] = "SAN ANDRÉS Y PROVIDENCIA"

# %%
homicides_df.loc[homicides_df["DEPARTAMENTO"] == "N. DE SANTANDER", "DEPARTAMENTO"] = "NORTE DE SANTANDER"

# %%
homicides_df["DEPARTAMENTO"].value_counts()
# Out:
# VALLE                       2596
# ANTIOQUIA                   1895
# CUNDINAMARCA                1799
# CAUCA                        591
# ATLÁNTICO                    568
# NARIÑO                       439
# BOLÍVAR                      403
# NORTE DE SANTANDER           366
# TOLIMA                       328
# RISARALDA                    313
# META                         306
# SANTANDER                    277
# QUINDÍO                      271
# CÓRDOBA                      266
# CALDAS                       219
# CESAR                        218
# HUILA                        204
# MAGDALENA                    192
# GUAJIRA                      183
# CAQUETÁ                      178
# CHOCÓ                        158
# PUTUMAYO                     145
# SUCRE                        131
# BOYACÁ                       112
# ARAUCA                        79
# CASANARE                      77
# GUAVIARE                      34
# SAN ANDRÉS Y PROVIDENCIA      18
# VICHADA                       17
# AMAZONAS                       9
# VAUPÉS                         5
# GUAINÍA                        2
# Name: DEPARTAMENTO, dtype: int64

# %%
# Detecting duplicates by "CÉDULA" column
duplicates_by_cedula = homicides_df.loc[homicides_df["CÉDULA"].duplicated(keep = False)]

# %%
duplicates_by_cedula.shape
# Out:
# (1627, 21)

# %%
# Showing some examples
duplicates_by_cedula.sort_values("CÉDULA", ascending = True).head(6)
# Out:
#                     FECHA DEPARTAMENTO      MUNICIPIO      DIA  \
# 4041  2015-05-03 23:30:00        CAUCA       EL TAMBO  Domingo
# 3810  2015-04-26 03:00:00    ANTIOQUIA   SAN JERÓNIMO  Domingo
# 693   2015-01-19 05:30:00    ANTIOQUIA         SALGAR    Lunes
# 10796 2015-11-20 03:00:00        VALLE      CALI (CT)  Viernes
# 2386  2015-03-14 02:00:00         META  FUENTE DE ORO   Sábado
# 138   2015-01-02 06:20:00        CAUCA         SOTARA  Viernes
#
#                     BARRIO    ZONA                      CLASE DE SITIO  \
# 4041           LA VICTORIA   RURAL         BARES, CANTINAS Y SIMILARES
# 3810              LA PLAYA  URBANA  HOTELES, RESIDENCIAS, Y SIMILARES.
# 693              LA HABANA  URBANA                       VIAS PUBLICAS
# 10796   POTRERO GRANDE E21  URBANA                       VIAS PUBLICAS
# 2386   VEREDA PUERTO NUEVO   RURAL         BARES, CANTINAS Y SIMILARES
# 138                 CENTRO   RURAL                       VIAS PUBLICAS
#
#              ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 4041        ARMA DE FUEGO         A PIE         A PIE  45.0  MASCULINO
# 3810   CUERDA/SOGA/CADENA         A PIE         A PIE  25.0  MASCULINO
# 693         ARMA DE FUEGO         A PIE         A PIE  58.0  MASCULINO
# 10796       ARMA DE FUEGO         A PIE         A PIE  21.0  MASCULINO
# 2386          ARMA BLANCA         A PIE         A PIE  42.0  MASCULINO
# 138           ARMA BLANCA         A PIE         A PIE  22.0  MASCULINO
#
#       ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  \
# 4041   UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 3810       SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA
# 693        SOLTERO           AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 10796      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA
# 2386       SOLTERO        INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA
# 138        SOLTERO    EMPLEADO EJERCITO  NO REPORTADO  SECUNDARIA  COLOMBIA
#
#        CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 4041    19256000.0             1970.0  10-048        aitufn1227@gmail.com
# 3810     5656000.0             1990.0  10-048  ibbcpu2509@unidatos.edu.co
# 693      5642000.0               57.0  10-079  unhoqj1172@unidatos.edu.co
# 10796   76001000.0             1994.0  10-079  iknnoj8430@unidatos.edu.co
# 2386    50287000.0             1973.0  10-255  afompq7113@unidatos.edu.co
# 138     19760000.0             1993.0  10-255  cobgqs8819@unidatos.edu.co

# %% [markdown]
# <span style="color:red">TODO: Delete records with "CÉDULA" duplicated</span>
#
# <span style="color:red">Hint: You can use drop_duplicates() function. Make sure to update original dataframe. Google it!</span>

# %%
homicides_df = homicides_df.drop_duplicates(subset=['CÉDULA'])

# %%
duplicates_by_cedula = homicides_df.loc[homicides_df["CÉDULA"].duplicated(keep = False)]

# %%
duplicates_by_cedula.shape
# Out:
# (0, 21)

# %%
# Using regular expressions for validating if "CÉDULA" values match the pattern XX-XXX
cedula_malformed = homicides_df.loc[homicides_df["CÉDULA"].astype(str).apply(lambda x: (re.match("\d{2}-\d{3}", x) is None))]

# %%
cedula_malformed.head(6)
# Out:
#                    FECHA DEPARTAMENTO          MUNICIPIO      DIA  \
# 172  2015-01-03 11:00:00         META            MESETAS   Sábado
# 1114 2015-02-01 12:30:00    ATLÁNTICO  BARRANQUILLA (CT)  Domingo
# 2119 2015-03-06 15:30:00        VALLE          CALI (CT)  Viernes
# 3309 2015-04-11 10:30:00      CAQUETÁ     FLORENCIA (CT)   Sávado
# 3409 2015-04-13 23:20:00      CÓRDOBA            SAHAGÚN    Lunes
# 3588 2015-04-19 20:00:00      BOLÍVAR     CARTAGENA (CT)  Domingo
#
#                             BARRIO    ZONA         CLASE DE SITIO  \
# 172                VEREDA EL CAFRE   RURAL         ZONA SELVÁTICA
# 1114                        LA LUZ  URBANA          VIAS PUBLICAS
# 2119           QUINTAS DEL SOL E14  URBANA  DENTRO DE LA VIVIENDA
# 3309                   VIA MORELIA   RURAL               CARCELES
# 3409  CORREGIMIENTO DE BAJO GRANDE  URBANA               BILLARES
# 3588                  LA ESPERANZA  URBANA          VIAS PUBLICAS
#
#           ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 172   MINA ANTIPERSONA         A PIE         A PIE  24.0  MASCULINO
# 1114     ARMA DE FUEGO         A PIE         A PIE  29.0  MASCULINO
# 2119       ARMA BLANCA         A PIE         A PIE  20.0   FEMENINO
# 3309         CORTANTES         A PIE         A PIE  23.0  MASCULINO
# 3409      CONTUNDENTES         A PIE         A PIE  49.0  MASCULINO
# 3588     ARMA DE FUEGO         A PIE         A PIE  45.0  MASCULINO
#
#      ESTADO CIVIL       CLASE EMPLEADO     PROFESION   ESCOLARIDAD  \
# 172       SOLTERO    EMPLEADO EJERCITO  NO REPORTADO    SECUNDARIA
# 1114      SOLTERO        INDEPENDIENTE  NO REPORTADO      PRIMARIA
# 2119  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA
# 3309      SOLTERO        INDEPENDIENTE  NO REPORTADO      PRIMARIA
# 3409      SOLTERO        INDEPENDIENTE  NO REPORTADO    SECUNDARIA
# 3588      SOLTERO          DESEMPLEADO  NO REPORTADO  NO REPORTADO
#
#          PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA  \
# 172       COLOMBIA   50330000.0             1991.0  680-21
# 1114      COLOMBIA    8001000.0             1986.0  140-17
# 2119      COLOMBIA   76001000.0             1995.0  975-31
# 3309      COLOMBIA   18001000.0             1992.0  348-66
# 3409      COLOMBIA   23660000.0             1966.0  496-18
# 3588  NO REPORTADO   13001000.0             1970.0  188-03
#
#                           CORREO
# 172         oohghd8899@gmail.com
# 1114  correo5853@colombia.gov.co
# 2119  ohbqrk3631@unidatos.edu.co
# 3309  pdkqur8407@unidatos.edu.co
# 3409  fdbbeo6751@unidatos.edu.co
# 3588  diebuo5651@unidatos.edu.co

# %% [markdown]
# <span style="color:red">TODO: Fix the malformed "CÉDULA" values. Make sure to update original dataframe.</span>

# %%
cedulaGuion = lambda x: x.replace("-", "")

# %%
celudaReplace = lambda x: x[:2] + '-' + x[2:]

# %%
cedulaBien = cedula_malformed["CÉDULA"].apply(cedulaGuion).apply(celudaReplace)

# %%
cedulaBien.head(20)
# Out:
# 172     68-021
# 1114    14-017
# 2119    97-531
# 3309    34-866
# 3409    49-618
# 3588    18-803
# 4565    92-874
# 4587    27-345
# 4971    55-963
# 5372    63-185
# 5532    98-100
# 5834    31-949
# 5849    47-307
# 6315    89-381
# 7885    85-455
# 8094    60-436
# 8183    35-223
# 8223    58-651
# 9033    57-014
# 9751    51-841
# Name: CÉDULA, dtype: object

# %% [markdown]
# <span style="color:red">TODO: Make something similar to check and fix the "CORREO" column (PATTERN: 4 digits before the @, only .edu.co and .com domains allowed)</span>

# %% [markdown]
# homicides_df["CÉDULA"].apply(cedulaGuion).apply(celudaReplace)

# %%
# Using regular expressions for validating if "CORREO" values match the pattern 4 digits before the @, only .edu.co and .com domains
correo_malformed = homicides_df.loc[homicides_df["CORREO"].astype(str).apply(lambda x: (re.match("^((?=[a-zA-Z])[a-zA-Z._0-9]+(?<!\.){4})@(?=[a-z])[a-z\-]+(?<!\-).('.edu.co'|'.co')+$", x) is None))]

# %%
correo_malformed.head(50)
# Out:
#                  FECHA DEPARTAMENTO               MUNICIPIO     DIA  \
# 0  2015-01-01 06:00:00    ANTIOQUIA                   AMAGÁ  Jueves
# 1  2015-01-01 09:00:00    ANTIOQUIA                 BARBOSA  Jueves
# 2  2015-01-01 19:00:00    ANTIOQUIA                EL BAGRE  Jueves
# 3  2015-01-01 11:20:00    ANTIOQUIA                  JARDÍN  Jueves
# 4  2015-01-01 15:00:00    ANTIOQUIA           MEDELLÍN (CT)   Juees
# 5  2015-01-01 00:47:00    ANTIOQUIA           MEDELLÍN (CT)   Juees
# 6  2015-01-01 11:00:00    ANTIOQUIA           MEDELLÍN (CT)  Jueves
# 7  2015-01-01 19:35:00    ANTIOQUIA           MEDELLÍN (CT)  Jueves
# 8  2015-01-01 20:35:00    ANTIOQUIA           MEDELLÍN (CT)  Jueves
# 9  2015-01-01 14:00:00    ANTIOQUIA                  MUTATÁ  Jueves
# 10 2015-01-01 05:00:00    ANTIOQUIA                 NECOCLÍ  Jueves
# 11 2015-01-01 23:30:00    ANTIOQUIA    SANTAFÉ DE ANTIOQUIA  Jueves
# 12 2015-01-01 09:30:00    ANTIOQUIA                 SEGOVIA  Jueves
# 13 2015-01-01 14:00:00    ANTIOQUIA                 TÁMESIS  Jueves
# 14 2015-01-01 14:40:00    ATLÁNTICO       BARRANQUILLA (CT)   Juees
# 15 2015-01-01 04:40:00    ATLÁNTICO       BARRANQUILLA (CT)  Jueces
# 16 2015-01-01 06:00:00    ATLÁNTICO       BARRANQUILLA (CT)  Jueves
# 17 2015-01-01 09:50:00    ATLÁNTICO       BARRANQUILLA (CT)  Jueves
# 18 2015-01-01 20:00:00    ATLÁNTICO       BARRANQUILLA (CT)  Jueves
# 19 2015-01-01 08:30:00    ATLÁNTICO                 SOLEDAD   juves
# 20 2015-01-01 07:25:00      BOLÍVAR          CARTAGENA (CT)  Juevrs
# 21 2015-01-01 07:50:00      BOLÍVAR          CARTAGENA (CT)   Juees
# 22 2015-01-01 18:20:00      BOLÍVAR          CARTAGENA (CT)  Jueves
# 23 2015-01-01 18:30:00       BOYACÁ                EL COCUY   Juees
# 24 2015-01-01 02:25:00       CALDAS          MANIZALES (CT)  Jueves
# 25 2015-01-01 06:30:00       CALDAS              MANZANARES  Jueves
# 26 2015-01-01 01:20:00       CALDAS                NORCASIA  Jueves
# 27 2015-01-01 22:30:00       CALDAS                VICTORIA  Jueves
# 28 2015-01-01 15:00:00      CAQUETÁ     SAN JOSÉ DEL FRAGUA  Jueces
# 29 2015-01-01 00:30:00      CAQUETÁ  SAN VICENTE DEL CAGUÁN  Jueves
# 30 2015-01-01 04:25:00     CASANARE                TRINIDAD  Jueves
# 31 2015-01-01 15:00:00        CAUCA                ALMAGUER  Juevrs
# 32 2015-01-01 10:00:00        CAUCA                 BOLÍVAR  Jueves
# 33 2015-01-01 11:30:00        CAUCA                 CAJIBÍO  Jueves
# 34 2015-01-01 21:00:00        CAUCA                  CALOTO  Jueves
# 35 2015-01-01 06:00:00        CAUCA                EL TAMBO  Jueves
# 36 2015-01-01 08:00:00        CAUCA                   PATÍA  Jueves
# 37 2015-01-01 08:00:00        CAUCA                   PATÍA  Jueves
# 38 2015-01-01 04:40:00        CAUCA                PIAMONTE  Jueves
# 39 2015-01-01 05:36:00        CAUCA            POPAYÁN (CT)  Jueves
# 40 2015-01-01 03:00:00        CAUCA           PUERTO TEJADA  Jueves
# 41 2015-01-01 09:15:00        CAUCA                   ROSAS  Jueves
# 42 2015-01-01 10:00:00        CAUCA  SANTANDER DE QUILICHAO  Jueves
# 43 2015-01-01 14:11:00        CESAR         VALLEDUPAR (CT)  Jueves
# 44 2015-01-01 17:33:00        CESAR         VALLEDUPAR (CT)  Jueves
# 45 2015-01-01 23:45:00        CHOCÓ                   LLORÓ  Jueves
# 46 2015-01-01 18:41:00        CHOCÓ             QUIBDÓ (CT)   Juees
# 47 2015-01-01 09:00:00        CHOCÓ                    TADÓ  Jueves
# 48 2015-01-01 14:30:00      CÓRDOBA              BUENAVISTA  Jueves
# 49 2015-01-01 18:40:00      CÓRDOBA        PUERTO ESCONDIDO  Jueves
#
#                         BARRIO    ZONA                      CLASE DE SITIO  \
# 0                    EL VOLCAN   RURAL                              TIENDA
# 1               VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2                PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                   CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4     PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 5       CORDOBA CNO REPORTADO7  URBANA                       VIAS PUBLICAS
# 6   CRISTO REY CNO REPORTADO15  URBANA                       VIAS PUBLICAS
# 7     LA SALLE  CNO REPORTADO3  URBANA                       VIAS PUBLICAS
# 8       KENNEDY CNO REPORTADO6  URBANA                       VIAS PUBLICAS
# 9                VDA CASA ROJA   RURAL                  FINCAS Y SIMILARES
# 10             CGTO. EL TOTUMO   RURAL                  FINCAS Y SIMILARES
# 11             SECTOR TERMINAL  URBANA                         LOTE BALDIO
# 12                       GALAN  URBANA                       VIAS PUBLICAS
# 13                   SAN PABLO   RURAL                  FINCAS Y SIMILARES
# 14                LAS AMERICAS  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 15                  BARLOVENTO  URBANA                       VIAS PUBLICAS
# 16                      REBOLO  URBANA                       VIAS PUBLICAS
# 17                      REBOLO  URBANA                       VIAS PUBLICAS
# 18                     POR FIN  URBANA                       VIAS PUBLICAS
# 19                   LAS MORAS  URBANA                       VIAS PUBLICAS
# 20              VIEJO PORVENIR  URBANA                       VIAS PUBLICAS
# 21               OLAYA HERRERA  URBANA                       VIAS PUBLICAS
# 22                    EL POZON  URBANA                       VIAS PUBLICAS
# 23                      CENTRO  URBANA                       VIAS PUBLICAS
# 24                     LINARES  URBANA                       VIAS PUBLICAS
# 25                VDA LA UNION   RURAL                              TIENDA
# 26                      CENTRO  URBANA         BARES, CANTINAS Y SIMILARES
# 27                      CENTRO  URBANA                            OFICINAS
# 28                      CENTRO  URBANA                          DISCOTECAS
# 29                SANTA ISABEL  URBANA                       VIAS PUBLICAS
# 30                   EL PALITO   RURAL                       VIAS PUBLICAS
# 31             VEREDA TARABITA   RURAL                                RIOS
# 32             VDA GUAYABILLAS   RURAL                  FINCAS Y SIMILARES
# 33             VDA CAMPOALEGRE   RURAL         BARES, CANTINAS Y SIMILARES
# 34                 VDA HUASANO   RURAL                 CASAS DE HABITACION
# 35             C/MIENTO PIAGUA   RURAL                           CARRETERA
# 36      C/MIENTO PIEDRASENTADA   RURAL                           CARRETERA
# 37      C/MIENTO PIEDRASENTADA   RURAL                           CARRETERA
# 38                    PIAMONTE  URBANA                       VIAS PUBLICAS
# 39             NUEVA ESPERANZA  URBANA                       VIAS PUBLICAS
# 40                LA ESPERANZA  URBANA                       VIAS PUBLICAS
# 41                      Centro  URBANA               ESCENARIOS DEPORTIVOS
# 42                     LIMONAR  URBANA                 CASAS DE HABITACION
# 43                  FUNDADORES  URBANA         BARES, CANTINAS Y SIMILARES
# 44               NUEVO MILENIO  URBANA                       VIAS PUBLICAS
# 45                 Nuevo Lloró  URBANA                       VIAS PUBLICAS
# 46                      OBRERO  URBANA                       VIAS PUBLICAS
# 47                     POPULAR  URBANA                       VIAS PUBLICAS
# 48                   EL CENTRO   RURAL                CLINICAS Y SIMILARES
# 49          VEREDA MOLINO ROJO   RURAL                  FINCAS Y SIMILARES
#
#           ARMA O MEDIO MOVIL VICTIMA          MOVIL AGRESOR  EDAD     GENERO  \
# 0          ARMA BLANCA         A PIE                  A PIE  44.0  MASCULINO
# 1          ARMA BLANCA         A PIE                  A PIE  30.0  MASCULINO
# 2          ARMA BLANCA         A PIE                  A PIE  33.0  MASCULINO
# 3          ARMA BLANCA         A PIE                  A PIE  40.0  MASCULINO
# 4         CONTUNDENTES         A PIE                  A PIE  66.0  MASCULINO
# 5        ARMA DE FUEGO         A PIE                  A PIE  42.0  MASCULINO
# 6          ARMA BLANCA         A PIE                  A PIE  25.0  MASCULINO
# 7          ARMA BLANCA         A PIE                  A PIE  37.0  MASCULINO
# 8        ARMA DE FUEGO         A PIE   PASAJERO MOTOCICLETA  25.0  MASCULINO
# 9          ARMA BLANCA         A PIE                  A PIE  30.0  MASCULINO
# 10         ARMA BLANCA         A PIE                  A PIE  41.0  MASCULINO
# 11       ARMA DE FUEGO         A PIE                  A PIE  30.0  MASCULINO
# 12         ARMA BLANCA         A PIE                  A PIE  29.0  MASCULINO
# 13         ARMA BLANCA         A PIE                  A PIE  40.0  MASCULINO
# 14       ARMA DE FUEGO         A PIE                  A PIE  21.0  MASCULINO
# 15       ARMA DE FUEGO         A PIE                  A PIE  20.0  MASCULINO
# 16       ARMA DE FUEGO         A PIE                  A PIE  32.0  MASCULINO
# 17       ARMA DE FUEGO         A PIE                  A PIE  39.0   FEMENINO
# 18       ARMA DE FUEGO         A PIE   PASAJERO MOTOCICLETA  17.0  MASCULINO
# 19       ARMA DE FUEGO         A PIE                  A PIE  33.0  MASCULINO
# 20       ARMA DE FUEGO         A PIE                  A PIE  28.0  MASCULINO
# 21       ARMA DE FUEGO         A PIE                  A PIE  20.0  MASCULINO
# 22         ARMA BLANCA         A PIE                  A PIE  18.0  MASCULINO
# 23         ARMA BLANCA         A PIE                  A PIE  32.0  MASCULINO
# 24       ARMA DE FUEGO         A PIE                  A PIE  23.0  MASCULINO
# 25       ARMA DE FUEGO         A PIE                  A PIE  32.0   FEMENINO
# 26         ARMA BLANCA         A PIE                  A PIE  38.0  MASCULINO
# 27  CUERDA/SOGA/CADENA         A PIE                  A PIE  50.0   FEMENINO
# 28       ARMA DE FUEGO         A PIE                  A PIE  24.0  MASCULINO
# 29         ARMA BLANCA         A PIE                  A PIE  42.0  MASCULINO
# 30         ARMA BLANCA         A PIE  CONDUCTOR MOTOCICLETA  25.0  MASCULINO
# 31       ARMA DE FUEGO         A PIE                  A PIE  30.0  MASCULINO
# 32       ARMA DE FUEGO         A PIE                  A PIE  42.0  MASCULINO
# 33         ARMA BLANCA         A PIE                  A PIE  41.0  MASCULINO
# 34         ARMA BLANCA         A PIE                  A PIE  35.0  MASCULINO
# 35         ARMA BLANCA         A PIE                  A PIE  17.0  MASCULINO
# 36       ARMA DE FUEGO      VEHICULO                  A PIE  26.0  MASCULINO
# 37       ARMA DE FUEGO      VEHICULO                  A PIE  38.0  MASCULINO
# 38         ARMA BLANCA         A PIE                  A PIE  24.0  MASCULINO
# 39         ARMA BLANCA         A PIE                  A PIE  40.0  MASCULINO
# 40       ARMA DE FUEGO         A PIE                  A PIE  21.0  MASCULINO
# 41           PUNZANTES         A PIE                  A PIE  22.0  MASCULINO
# 42         ARMA BLANCA         A PIE                  A PIE  34.0  MASCULINO
# 43       ARMA DE FUEGO         A PIE                  A PIE  31.0  MASCULINO
# 44       ARMA DE FUEGO         A PIE                  A PIE  22.0  MASCULINO
# 45         ARMA BLANCA         A PIE                  A PIE  58.0  MASCULINO
# 46       ARMA DE FUEGO         A PIE                  A PIE  31.0  MASCULINO
# 47       ARMA DE FUEGO         A PIE                  A PIE  34.0  MASCULINO
# 48        CONTUNDENTES         A PIE                  A PIE  24.0   FEMENINO
# 49         ARMA BLANCA         A PIE                  A PIE  20.0   FEMENINO
#
#    ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  \
# 0        CASADO        INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 1       SOLTERO          DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO
# 2   UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 3        CASADO           AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 4   UNION LIBRE          DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA
# 5       SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 6       SOLTERO          DESEMPLEADO  NO REPORTADO  SECUNDARIA      COLOMBIA
# 7        CASADO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 8       SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 9       SOLTERO       ETNIA INDIGENA  NO REPORTADO  SECUNDARIA  NO REPORTADO
# 10  UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 11      SOLTERO          DESEMPLEADO  NO REPORTADO  ANALFABETA      COLOMBIA
# 12      SOLTERO        INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 13      SOLTERO           AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 14      SOLTERO        INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 15      SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 16  UNION LIBRE        INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 17      SOLTERO          COMERCIANTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 18      SOLTERO          DESEMPLEADO  NO REPORTADO  SECUNDARIA      COLOMBIA
# 19      SOLTERO        INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 20      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA      COLOMBIA
# 21      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA      COLOMBIA
# 22      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA      COLOMBIA
# 23  UNION LIBRE        INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 24      SOLTERO          DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA
# 25  UNION LIBRE          AMA DE CASA  NO REPORTADO    PRIMARIA      COLOMBIA
# 26  UNION LIBRE        INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 27  UNION LIBRE          AMA DE CASA  NO REPORTADO    PRIMARIA      COLOMBIA
# 28  UNION LIBRE        INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 29  UNION LIBRE        INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 30  UNION LIBRE        INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 31  UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 32  UNION LIBRE        INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 33  UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 34      SOLTERO           AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 35      SOLTERO           ESTUDIANTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 36      SOLTERO    EMPLEADO EJERCITO  NO REPORTADO  SECUNDARIA      COLOMBIA
# 37  UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 38  UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 39      SOLTERO        INDEPENDIENTE  NO REPORTADO  ANALFABETA      COLOMBIA
# 40      SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 41  UNION LIBRE           AGRICULTOR  NO REPORTADO  SECUNDARIA      COLOMBIA
# 42  UNION LIBRE        INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 43  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA      COLOMBIA
# 44      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA      COLOMBIA
# 45      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA      COLOMBIA
# 46  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO    PRIMARIA      COLOMBIA
# 47       CASADO    EMPLEADO POLICIAL       POLICIA     TECNICO      COLOMBIA
# 48      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA      COLOMBIA
# 49  UNION LIBRE          AMA DE CASA  NO REPORTADO  SECUNDARIA      COLOMBIA
#
#     CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0     5030000.0             1971.0  42-908  agbnqg2122@unidatos.edu.co
# 1     5079000.0             1985.0  15-183        rbkeui3584@gmail.com
# 2     5250000.0             1982.0  84-786  aorkhf9155@unidatos.edu.co
# 3     5364000.0             1975.0  31-289  dhtemr6623@unidatos.edu.co
# 4     5001000.0             1949.0  66-363  artatj9268@unidatos.edu.co
# 5     5001000.0             1973.0  54-450  grlcsj8696@unidatos.edu.co
# 6     5001000.0             1990.0  45-052        pkdakc6682@gmail.com
# 7     5001000.0             1978.0  45-298        qledtq1884@gmail.com
# 8     5001000.0             1990.0  37-281  mipgfg2758@unidatos.edu.co
# 9     5480000.0             1985.0  78-013  dgepmg5536@unidatos.edu.co
# 10    5490000.0             1974.0  23-787  lngclq5845@unidatos.edu.co
# 11    5042000.0             1985.0  49-898  alsmgs8974@unidatos.edu.co
# 12    5736000.0             1986.0  98-587  inugoi5195@unidatos.edu.co
# 13    5789000.0             1975.0  39-330        nsirqk5181@gmail.com
# 14    8001000.0             1994.0  26-603  nnofur6404@unidatos.edu.co
# 15    8001000.0             1995.0  51-967  clfagt5842@unidatos.edu.co
# 16    8001000.0             1983.0  65-056  bspmmr7169@unidatos.edu.co
# 17    8001000.0             1976.0  33-026  ibuoap4440@unidatos.edu.co
# 18    8001000.0             1998.0  83-291  qdqasa2516@unidatos.edu.co
# 19    8758000.0             1982.0  52-287        shfbpo7917@gmail.com
# 20   13001000.0             1987.0  67-286        oltuqp7633@gmail.com
# 21   13001000.0             1995.0  68-207        qlsalf8118@gmail.com
# 22   13001000.0             1997.0  12-513        uieile5235@gmail.com
# 23   15244000.0             1983.0  73-104        psahbq8570@gmail.com
# 24   17001000.0             1992.0  29-093        mjaode4217@gmail.com
# 25   17433000.0             1983.0  31-907  lqgmsn5798@unidatos.edu.co
# 26   17495000.0             1977.0  81-127        gpumjf2145@gmail.com
# 27   17867000.0             1965.0  16-311  amstkm9969@unidatos.edu.co
# 28   18610000.0             1991.0  94-565   correo975@unidatos.edu.co
# 29   18753000.0             1973.0  20-565  ipeeun1893@unidatos.edu.co
# 30   85430000.0             1990.0  32-425        gcdfpa5305@gmail.com
# 31   19022000.0             1985.0  70-422  skqqtn4490@unidatos.edu.co
# 32   19100000.0             1973.0  67-078        jteacs7755@gmail.com
# 33   19130000.0             1974.0  15-174  klkust2304@unidatos.edu.co
# 34   19142000.0             1980.0  28-738  ddpgtc1130@unidatos.edu.co
# 35   19256000.0             1998.0  13-325  sieqgn1354@unidatos.edu.co
# 36   19532000.0             1989.0  69-084  correo4714@colombia.gov.co
# 37   19532000.0             1977.0  29-165  fchgua5918@unidatos.edu.co
# 38   19533000.0             1991.0  79-680        tfhmne5526@gmail.com
# 39   19001000.0             1975.0  54-612  rbpnbu7562@unidatos.edu.co
# 40   19573000.0             1994.0  12-747  edtctk5494@unidatos.edu.co
# 41   19622000.0             1993.0  82-521        psljcq7254@gmail.com
# 42   19698000.0             1981.0  55-493  uigcqd2444@unidatos.edu.co
# 43   20001000.0             1984.0  52-681        bojjbp2191@gmail.com
# 44   20001000.0             1993.0  90-024        deluml6131@gmail.com
# 45   27413000.0             1957.0  65-723  thsljg8846@unidatos.edu.co
# 46   27001000.0             1984.0  72-741        gujbih5278@gmail.com
# 47   27787000.0             1981.0  29-957  correo8297@colombia.gov.co
# 48   23079000.0             1991.0  95-418  uupgaj4995@unidatos.edu.co
# 49   23574000.0             1995.0  93-694  qifdmr1704@unidatos.edu.co

# %%
funcion1 = lambda x: x["CORREO"].str.split('@').str[1]

# %%
funcion2 = lambda x: x[:4]

# %%
def funcion(x):
   correoParte1 = x[:4]
   correoParte2 = x.split('@')[1]
   return correoParte1 + '@' + correoParte2

# %%
correo_malformed["CORREO"] = correo_malformed["CORREO"].apply(lambda x: funcion(x))

# %%
correo_malformed["CORREO"]
# Out:
# 0        agbn@unidatos.edu.co
# 1              rbke@gmail.com
# 2        aork@unidatos.edu.co
# 3        dhte@unidatos.edu.co
# 4        arta@unidatos.edu.co
#                  ...
# 12394          nggi@gmail.com
# 12395    corr@colombia.gov.co
# 12396    fkta@unidatos.edu.co
# 12397          gafk@gmail.com
# 12398    corr@unidatos.edu.co
# Name: CORREO, Length: 11563, dtype: object

# %%
#homicidioCorreoMalFormed

# %%
# Calculating the distance between two words using the Levenshtein method
pylev.levenshtein('sábado', 'sabaod')
# Out:
# 3

# %%
pylev.levenshtein('sábado', 'viernes')
# Out:
# 7

# %% [markdown]
# <span style="color:red">TODO: Create a function to fix the digitation errors for column "DIA". Make sure to update original dataframe.</span>

# %%
# Showing different values for "DIA" column
homicides_df["DIA"].unique()
# Out:
# array(['Jueves', 'Juees', 'Jueces', 'juves', 'Juevrs', 'Viernes',
#        'Viermes', 'iernes', 'virnes', 'Vierens', 'Sábado', 'Sabadi',
#        'Sabado', 'sábad', 'Sávado', 'Ssbado', 'Domingo', 'Domungo',
#        'Doningo', 'domungo', 'Lunes', 'lune', 'Luns', 'Lumes', 'kunes',
#        'Lnues', 'Martes', 'Mates', 'Marte', 'mates', 'Miércoles',
#        'Miwrcoles', 'Mircoles', 'Voernes', 'domnigo', 'Maryes',
#        'Miercoles', 'miércles', 'Dominog', 'Msrtes', 'Mirrcoles'],
#       dtype=object)

# %%
homicides_df.loc[(homicides_df["DIA"] == "Jueves") | (homicides_df["DIA"] == "Juees") | (homicides_df["DIA"] == "Jueces") | (homicides_df["DIA"] == "juves") | (homicides_df["DIA"] == "Juevrs") , "DIA"] = "jueves"

# %%
homicides_df.loc[(homicides_df["DIA"] == "Viernes") | (homicides_df["DIA"] == "Viermes") | (homicides_df["DIA"] == "iernes") | (homicides_df["DIA"] == "virnes") | (homicides_df["DIA"] == "Vierens") | (homicides_df["DIA"] == "Voernes") , "DIA"] = "viernes"

# %%
homicides_df.loc[(homicides_df["DIA"] == "Sábado") | (homicides_df["DIA"] == "Sabadi") | (homicides_df["DIA"] == "Sabado") | (homicides_df["DIA"] == "sábad") | (homicides_df["DIA"] == "Sávado") | (homicides_df["DIA"] == "Ssbado") , "DIA"] = "sábado"

# %%
homicides_df.loc[(homicides_df["DIA"] == "Domingo") | (homicides_df["DIA"] == "Domungo") | (homicides_df["DIA"] == "Doningo") | (homicides_df["DIA"] == "domungo") | (homicides_df["DIA"] == "Dominog") | (homicides_df["DIA"] == "domnigo")  , "DIA"] = "domingo"

# %%
homicides_df.loc[(homicides_df["DIA"] == "Lunes") | (homicides_df["DIA"] == "lune") | (homicides_df["DIA"] == "Luns") | (homicides_df["DIA"] == "Lumes") | (homicides_df["DIA"] == "kunes") | (homicides_df["DIA"] == "Lnues")  , "DIA"] = "lunes"

# %%
homicides_df.loc[(homicides_df["DIA"] == "Martes") | (homicides_df["DIA"] == "Mates") | (homicides_df["DIA"] == "Marte") | (homicides_df["DIA"] == "mates") | (homicides_df["DIA"] == "Maryes") | (homicides_df["DIA"] == "Msrtes")  , "DIA"] = "martes"

# %%
homicides_df.loc[(homicides_df["DIA"] == "Miércoles") | (homicides_df["DIA"] == "Miwrcoles") | (homicides_df["DIA"] == "Mircoles") | (homicides_df["DIA"] == "Miercoles") | (homicides_df["DIA"] == "miércles") | (homicides_df["DIA"] == "Mirrcoles")  , "DIA"] = "miércoles"

# %%
homicides_df["DIA"].unique()
# Out:
# array(['jueves', 'viernes', 'sábado', 'domingo', 'lunes', 'martes',
#        'miércoles'], dtype=object)

# %%
homicides_df[["AÑO DE NACIMIENTO", "EDAD"]].head(10)
# Out:
#    AÑO DE NACIMIENTO  EDAD
# 0             1971.0  44.0
# 1             1985.0  30.0
# 2             1982.0  33.0
# 3             1975.0  40.0
# 4             1949.0  66.0
# 5             1973.0  42.0
# 6             1990.0  25.0
# 7             1978.0  37.0
# 8             1990.0  25.0
# 9             1985.0  30.0

# %% [markdown]
# <span style="color:red">TODO: Check and fix, if apply, the column "AÑO DE NACIMIENTO", using the column "EDAD". Make sure to update original dataframe.</span>

# %%
homicides_df['AÑO DE NACIMIENTO'] = np.where((homicides_df['AÑO DE NACIMIENTO'] != (2022 - homicides_df['EDAD'])),(2022 - homicides_df['EDAD']),homicides_df['AÑO DE NACIMIENTO'])

# %%
homicides_df[["AÑO DE NACIMIENTO", "EDAD"]].head(10)
# Out:
#    AÑO DE NACIMIENTO  EDAD
# 0             1978.0  44.0
# 1             1992.0  30.0
# 2             1989.0  33.0
# 3             1982.0  40.0
# 4             1956.0  66.0
# 5             1980.0  42.0
# 6             1997.0  25.0
# 7             1985.0  37.0
# 8             1997.0  25.0
# 9             1992.0  30.0
